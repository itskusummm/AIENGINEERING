# %%
## 1. Finish the ticket-price exercise
# Complete `ticket_price.py` including the `is_student` 20%-discount stretch.
ticket_price = 700
is_student = True
if is_student:
    ticket_price *= 0.8 

print(f"Ticket price: {ticket_price}")
# Out:
# Ticket price: 560.0

# %%
# Comprehension
ticket_price = 700
is_student = True
ticket_price_comp = ticket_price * 0.8 if is_student else ticket_price
print(f"Ticket price: {ticket_price_comp}")
# Out:
# Ticket price: 560.0

# %%
# ## 3. Password check
# Write `password_check.py`:
# - Store a secret, e.g. `secret = "saarathi"`.
# - Store an `attempt`.
# - If `attempt == secret`, print `"Access granted"`, else `"Denied"`.
# - **Stretch:** also require the attempt to be at least 6 characters using `and`.

secret = "saarathi"
attempt = input("Enter password: ")
if attempt == secret and len(attempt) >=6:
    print('Access Granted')
else:
    print('Denied')

# %%
# ## 4. String practice — predict then run
# ```python
s = "Artificial Intelligence"
print(s.lower())
print(s.replace(" ", "_"))
print(s.split())
print(len(s))
print(s[:10])
print(f"{s} has {len(s)} chars")
# ```
# Write your prediction as a comment beside each line.
# Out:
# artificial intelligence
# Artificial_Intelligence
# ['Artificial', 'Intelligence']
# 23
# Artificial
# Artificial Intelligence has 23 chars
