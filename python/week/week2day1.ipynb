# %%
a=[1,2,3]
sum=0
for i in a:
    sum=sum+i
print(sum)
# Out:
# 6

# %%
def greet(name):
    return f"Hello, {name}!"
name=['Kusumm', 'Alice', 'Bob']

for i in name:
    print(greet(i))
# Out:
# Hello, Kusumm!
# Hello, Alice!
# Hello, Bob!

# %%
dict= {"name": "Kusumm", "course": "AIEngineering", "city": "New York"}

def print_dict(dict):
    return "\n".join(f"{k}: {v}" for k, v in dict.items())
    
print(print_dict(dict))
# Out:
# name: Kusumm
# course: AIEngineering
# city: New York
